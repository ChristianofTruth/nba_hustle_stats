# %%
# !pip install nba_api

# %%
# !pip install nba_py

# %%
#!pip install selenium

# %%
# %matplotlib inline
from selenium import webdriver
from pandas import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import *
from bs4 import BeautifulSoup

# %%
url = "https://stats.nba.com/teams/hustle/?Season=2018-19&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

# %%
soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

df_list = pd.read_html(table.prettify())

# %%
df_list
# Out:
# [                      TEAM   MIN  Screen  Assists  Screen  Assists PTS  \
#  0            Atlanta Hawks  96.9              8.0                 18.2
#  1           Boston Celtics  96.5              8.6                 20.0
#  2            Brooklyn Nets  97.5             11.0                 26.2
#  3        Charlotte Hornets  96.7             11.1                 25.7
#  4            Chicago Bulls  97.1              8.3                 18.6
#  5      Cleveland Cavaliers  96.4              9.8                 22.4
#  6         Dallas Mavericks  96.5              8.5                 20.1
#  7           Denver Nuggets  96.2              9.0                 19.9
#  8          Detroit Pistons  96.9              9.4                 21.6
#  9    Golden State Warriors  96.6             10.7                 26.3
#  10         Houston Rockets  96.7              6.8                 16.6
#  11          Indiana Pacers  96.1              9.0                 20.2
# ...

# %%
hustle_nba_19 = df_list[0]
hustle_nba_19.columns
# Out:
# Index(['TEAM', 'MIN', 'Screen  Assists', 'Screen  Assists PTS', 'Deflections',
#        'OFF Loose Balls  Recovered', 'DEF Loose Balls  Recovered',
#        'Loose Balls  Recovered', '% Loose Balls  Recovered OFF',
#        '% Loose Balls  Recovered DEF', 'Charges  Drawn',
#        'Contested  2PT Shots', 'Contested  3PT Shots', 'Contested  Shots'],
#       dtype='object')

# %%
def nba_2019(team):
  return "2019 {:}".format(team)

def nba_2018(team):
  return "2018 {:}".format(team)

def nba_2017(team):
  return "2017 {:}".format(team)

def nba_2016(team):
  return "2016 {:}".format(team)

def nba_2015(team):
  return "2015 {:}".format(team)

# %%
hustle_nba_19['TEAM'] = hustle_nba_19['TEAM'].map(nba_2019)
hustle_nba_19.head()
# Out:
#                      TEAM   MIN  Screen  Assists  Screen  Assists PTS  \
# 0      2019 Atlanta Hawks  96.9              8.0                 18.2
# 1     2019 Boston Celtics  96.5              8.6                 20.0
# 2      2019 Brooklyn Nets  97.5             11.0                 26.2
# 3  2019 Charlotte Hornets  96.7             11.1                 25.7
# 4      2019 Chicago Bulls  97.1              8.3                 18.6
#
#    Deflections  OFF Loose Balls  Recovered  DEF Loose Balls  Recovered  \
# 0         14.5                         4.5                         5.0
# 1         14.1                         3.2                         5.1
# 2         12.1                         3.8                         4.2
# 3         12.6                         3.3                         4.8
# 4         12.6                         3.2                         4.7
#
#    Loose Balls  Recovered  % Loose Balls  Recovered OFF  \
# 0                     9.5                          47.0
# ...

# %%
url = "https://stats.nba.com/teams/hustle/?Season=2017-18&SeasonType=Regular%20Season&sort=TEAM_NAME&dir=1"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

# %%
soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

df_list2 = pd.read_html(table.prettify())

# %%
hustle_nba_2018 = df_list2[0]
hustle_nba_2018["TEAM"] = hustle_nba_2018["TEAM"].map(nba_2018)
hustle_nba_2018.head()
# Out:
#                       TEAM   MIN  Screen  Assists  Screen  Assists PTS  \
# 0  2018 Washington Wizards  96.9             10.6                 23.9
# 1           2018 Utah Jazz  96.4             10.5                 24.4
# 2     2018 Toronto Raptors  96.7              9.4                 21.9
# 3   2018 San Antonio Spurs  96.2              8.2                 18.3
# 4    2018 Sacramento Kings  96.4              9.2                 20.8
#
#    Deflections  OFF Loose Balls  Recovered  DEF Loose Balls  Recovered  \
# 0         14.9                         3.1                         4.9
# 1         15.1                         3.1                         4.9
# 2         14.8                         3.5                         4.8
# 3         14.4                         3.5                         4.6
# 4         14.0                         3.5                         4.8
#
#    Loose Balls  Recovered  % Loose Balls  Recovered OFF  \
# ...

# %%
url = "https://stats.nba.com/teams/hustle/?Season=2016-17&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

df_list3 = pandas.read_html(table.prettify())

# %%
hustle_nba_2017 = df_list3[0]
hustle_nba_2017["TEAM"] = hustle_nba_2017["TEAM"].map(nba_2017)
hustle_nba_2017.head()
# Out:
#                      TEAM   MIN  Screen  Assists  Screen  Assists PTS  \
# 0      2017 Atlanta Hawks  97.0             10.8                 23.8
# 1     2017 Boston Celtics  96.4             10.0                 23.5
# 2      2017 Brooklyn Nets  96.4              7.8                 18.0
# 3  2017 Charlotte Hornets  96.7             13.1                 30.3
# 4      2017 Chicago Bulls  96.5              8.2                 17.8
#
#    Deflections  OFF Loose Balls  Recovered  DEF Loose Balls  Recovered  \
# 0         16.8                         0.0                         0.0
# 1         15.4                         0.0                         0.0
# 2         14.4                         0.0                         0.0
# 3         13.8                         0.0                         0.0
# 4         14.9                         0.0                         0.0
#
#    Loose Balls  Recovered  % Loose Balls  Recovered OFF  \
# 0                     6.7                           0.0
# ...

# %%
reg_season_hustle = pd.concat([hustle_nba_19, hustle_nba_2018, hustle_nba_2017])

reg_hustle_sorted= reg_season_hustle.sort_values(by=["Deflections"], ascending=False)
reg_hustle_sorted
# Out:
#                            TEAM   MIN  Screen  Assists  Screen  Assists PTS  \
# 9    2017 Golden State Warriors  96.5             12.8                 29.9
# 29      2017 Washington Wizards  96.9             11.7                 25.7
# 22      2017 Philadelphia 76ers  96.7              7.4                 16.9
# 27         2017 Toronto Raptors  96.5             12.1                 26.2
# 9    2018 Oklahoma City Thunder  96.7              9.6                 22.1
# 0            2017 Atlanta Hawks  97.0             10.8                 23.8
# 11          2017 Indiana Pacers  96.9             10.1                 23.0
# 18    2017 New Orleans Pelicans  97.1              8.5                 19.3
# 18          2018 Indiana Pacers  96.4              9.9                 21.9
# 14       2017 Memphis Grizzlies  97.1              8.2                 19.5
# 17  2017 Minnesota Timberwolves  96.6              8.9                 19.8
# ...

# %%
reg_hustle_sorted.head()
# Out:
#                           TEAM   MIN  Screen  Assists  Screen  Assists PTS  \
# 9   2017 Golden State Warriors  96.5             12.8                 29.9
# 29     2017 Washington Wizards  96.9             11.7                 25.7
# 22     2017 Philadelphia 76ers  96.7              7.4                 16.9
# 27        2017 Toronto Raptors  96.5             12.1                 26.2
# 9   2018 Oklahoma City Thunder  96.7              9.6                 22.1
#
#     Deflections  OFF Loose Balls  Recovered  DEF Loose Balls  Recovered  \
# 9          18.7                         0.0                         0.0
# 29         18.5                         0.0                         0.0
# 22         17.8                         0.0                         0.0
# 27         17.0                         0.0                         0.0
# 9          16.8                         4.1                         5.5
#
#     Loose Balls  Recovered  % Loose Balls  Recovered OFF  \
# ...

# %%
url = "https://stats.nba.com/teams/advanced/?sort=W&dir=-1&Season=2018-19&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

advanced_df_list19 = pandas.read_html(table.prettify())

# %%
advanced_19 = advanced_df_list19[0]
advanced_19["TEAM"] = advanced_19["TEAM"].map(nba_2019)
advanced_19.head()
# Out:
#    Unnamed: 0                        TEAM  GP   W   L     MIN  OffRtg  DefRtg  \
# 0           1        2019 Milwaukee Bucks  82  60  22  3956.0   113.5   104.9
# 1           2        2019 Toronto Raptors  82  58  24  3976.0   112.6   106.8
# 2           3  2019 Golden State Warriors  82  57  25  3961.0   115.0   108.6
# 3           4         2019 Denver Nuggets  82  54  28  3946.0   112.1   108.1
# 4           5        2019 Houston Rockets  82  53  29  3966.0   114.9   110.1
#
#    NetRtg  AST%  ...  AST/TO RANK  AST  Ratio RANK  OREB% RANK  DREB% RANK  \
# 0     8.6  60.1  ...          NaN              NaN         NaN         NaN
# 1     5.8  60.3  ...          NaN              NaN         NaN         NaN
# 2     6.5  66.8  ...          NaN              NaN         NaN         NaN
# 3     4.0  65.3  ...          NaN              NaN         NaN         NaN
# 4     4.8  54.1  ...          NaN              NaN         NaN         NaN
#
# ...

# %%
advanced_19.columns
# Out:
# Index(['Unnamed: 0', 'TEAM', 'GP', 'W', 'L', 'MIN', 'OffRtg', 'DefRtg',
#        'NetRtg', 'AST%', 'AST/TO', 'AST  Ratio', 'OREB%', 'DREB%', 'REB%',
#        'TOV%', 'eFG%', 'TS%', 'PACE', 'PIE', 'GP RANK', 'W RANK', 'L RANK',
#        'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
#        'AST/TO RANK', 'AST  Ratio RANK', 'OREB% RANK', 'DREB% RANK',
#        'REB% RANK', 'TO  Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
#        'PIE RANK'],
#       dtype='object')

# %%
advanced_19.drop(columns=['GP RANK', 'W RANK', 'L RANK',
       'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
       'AST/TO RANK', 'AST  Ratio RANK', 'OREB% RANK', 'DREB% RANK',
       'REB% RANK', 'TO  Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
       'PIE RANK'], inplace=True)

advanced_19.drop(columns=["Unnamed: 0"], inplace=True)
advanced_19.head()
# Out:
#                          TEAM  GP   W   L     MIN  OffRtg  DefRtg  NetRtg  \
# 0        2019 Milwaukee Bucks  82  60  22  3956.0   113.5   104.9     8.6
# 1        2019 Toronto Raptors  82  58  24  3976.0   112.6   106.8     5.8
# 2  2019 Golden State Warriors  82  57  25  3961.0   115.0   108.6     6.5
# 3         2019 Denver Nuggets  82  54  28  3946.0   112.1   108.1     4.0
# 4        2019 Houston Rockets  82  53  29  3966.0   114.9   110.1     4.8
#
#    AST%  AST/TO  AST  Ratio  OREB%  DREB%  REB%  TOV%  eFG%   TS%    PACE  \
# 0  60.1    1.88        18.3   25.0   75.7  51.6  13.3  55.0  58.3  103.57
# 1  60.3    1.81        18.2   26.5   72.6  50.2  13.8  54.3  57.9  100.52
# 2  66.8    2.06        20.4   25.7   72.7  50.5  13.9  56.5  59.6  101.73
# 3  65.3    2.04        19.3   30.8   74.4  52.4  13.6  52.7  55.8   98.49
# 4  54.1    1.59        15.9   26.9   70.0  48.1  13.5  54.2  58.1   98.39
#
#     PIE
# 0  55.3
# 1  53.3
# 2  54.6
# 3  52.4
# 4  49.8

# %%
url = "https://stats.nba.com/teams/advanced/?sort=W&dir=-1&Season=2017-18&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

advanced_df_list18 = pandas.read_html(table.prettify())

# %%
advanced_18 = advanced_df_list18[0]
advanced_18["TEAM"] = advanced_18["TEAM"].map(nba_2018)

advanced_18.drop(columns=['Unnamed: 0','GP RANK', 'W RANK', 'L RANK',
       'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
       'AST/TO RANK', 'AST  Ratio RANK', 'OREB% RANK', 'DREB% RANK',
       'REB% RANK', 'TO  Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
       'PIE RANK'], inplace=True)

advanced_18.head()
# Out:
#                          TEAM  GP   W   L     MIN  OffRtg  DefRtg  NetRtg  \
# 0        2018 Houston Rockets  82  65  17  3951.0   114.1   105.7     8.4
# 1        2018 Toronto Raptors  82  59  23  3966.0   113.0   105.3     7.7
# 2  2018 Golden State Warriors  82  58  24  3946.0   112.8   106.8     5.9
# 3         2018 Boston Celtics  82  55  27  3961.0   106.8   103.2     3.6
# 4     2018 Philadelphia 76ers  82  52  30  3956.0   108.5   103.9     4.6
#
#    AST%  AST/TO  AST  Ratio  OREB%  DREB%  REB%  TOV%  eFG%   TS%    PACE  \
# 0  55.7    1.56        16.4   25.4   75.0  50.3  14.1  55.1  59.0   98.02
# 1  59.0    1.82        17.9   27.4   72.5  50.2  13.5  53.9  57.5   98.02
# 2  68.5    1.90        20.9   24.3   71.2  49.7  15.3  56.9  60.3  100.35
# 3  58.6    1.60        17.0   26.3   73.9  50.4  14.4  51.8  55.2   96.75
# 4  66.3    1.64        19.1   28.6   73.6  52.0  16.3  53.5  56.8  100.75
#
#     PIE
# 0  53.1
# 1  53.8
# 2  55.4
# 3  51.9
# 4  54.2

# %%
url = "https://stats.nba.com/teams/advanced/?sort=W&dir=-1&Season=2016-17&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

advanced_df_list17 = pd.read_html(table.prettify())

# %%
advanced_17 = advanced_df_list17[0]
advanced_17["TEAM"] = advanced_17["TEAM"].map(nba_2017)

advanced_17.drop(columns=['Unnamed: 0','GP RANK', 'W RANK', 'L RANK',
       'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
       'AST/TO RANK', 'AST  Ratio RANK', 'OREB% RANK', 'DREB% RANK',
       'REB% RANK', 'TO  Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
       'PIE RANK'], inplace=True)

advanced_17.head()
# Out:
#                          TEAM  GP   W   L     MIN  OffRtg  DefRtg  NetRtg  \
# 0  2017 Golden State Warriors  82  67  15  3956.0   114.8   103.4    11.4
# 1      2017 San Antonio Spurs  82  61  21  3961.0   110.3   102.9     7.4
# 2        2017 Houston Rockets  82  55  27  3956.0   114.1   108.4     5.7
# 3         2017 Boston Celtics  82  53  29  3951.0   110.6   108.0     2.6
# 4    2017 Cleveland Cavaliers  82  51  31  3976.0   112.8   109.7     3.1
#
#    AST%  AST/TO  AST  Ratio  OREB%  DREB%  REB%  TOV%  eFG%   TS%    PACE  \
# 0  70.5    2.06        21.2   27.2   70.9  50.4  14.6  56.3  59.7  100.37
# 1  60.6    1.77        18.1   28.2   73.0  51.1  14.1  52.4  56.4   94.86
# 2  62.6    1.67        18.1   28.1   71.7  49.9  15.0  54.5  58.3  100.55
# 3  65.3    1.90        18.8   25.9   70.5  48.5  13.6  52.5  56.7   97.21
# 4  56.7    1.66        17.1   26.4   72.2  49.9  14.0  54.7  58.0   96.74
#
#     PIE
# 0  57.9
# 1  55.1
# 2  51.6
# 3  51.4
# 4  51.0

# %%
reg_season_adv = pd.concat([advanced_19, advanced_18, advanced_17])
reg_adv_sorted = reg_season_adv.sort_values(by='NetRtg', ascending=False)
reg_adv_sorted
# Out:
#                            TEAM  GP   W   L     MIN  OffRtg  DefRtg  NetRtg  \
# 0    2017 Golden State Warriors  82  67  15  3956.0   114.8   103.4    11.4
# 0          2019 Milwaukee Bucks  82  60  22  3956.0   113.5   104.9     8.6
# 0          2018 Houston Rockets  82  65  17  3951.0   114.1   105.7     8.4
# 1          2018 Toronto Raptors  82  59  23  3966.0   113.0   105.3     7.7
# 1        2017 San Antonio Spurs  82  61  21  3961.0   110.3   102.9     7.4
# 2    2019 Golden State Warriors  82  57  25  3961.0   115.0   108.6     6.5
# 2    2018 Golden State Warriors  82  58  24  3946.0   112.8   106.8     5.9
# 1          2019 Toronto Raptors  82  58  24  3976.0   112.6   106.8     5.8
# 2          2017 Houston Rockets  82  55  27  3956.0   114.1   108.4     5.7
# 7                2019 Utah Jazz  82  50  32  3951.0   110.3   105.3     5.0
# 4          2019 Houston Rockets  82  53  29  3966.0   114.9   110.1     4.8
# ...

# %%
reg_adv_sorted["net_rtg_rank"] = reg_adv_sorted['NetRtg'].rank(ascending=False).astype("int")
reg_adv_sorted
# Out:
#                            TEAM  GP   W   L     MIN  OffRtg  DefRtg  NetRtg  \
# 0    2017 Golden State Warriors  82  67  15  3956.0   114.8   103.4    11.4
# 0          2019 Milwaukee Bucks  82  60  22  3956.0   113.5   104.9     8.6
# 0          2018 Houston Rockets  82  65  17  3951.0   114.1   105.7     8.4
# 1          2018 Toronto Raptors  82  59  23  3966.0   113.0   105.3     7.7
# 1        2017 San Antonio Spurs  82  61  21  3961.0   110.3   102.9     7.4
# 2    2019 Golden State Warriors  82  57  25  3961.0   115.0   108.6     6.5
# 2    2018 Golden State Warriors  82  58  24  3946.0   112.8   106.8     5.9
# 1          2019 Toronto Raptors  82  58  24  3976.0   112.6   106.8     5.8
# 2          2017 Houston Rockets  82  55  27  3956.0   114.1   108.4     5.7
# 7                2019 Utah Jazz  82  50  32  3951.0   110.3   105.3     5.0
# 4          2019 Houston Rockets  82  53  29  3966.0   114.9   110.1     4.8
# ...

# %%
url = "https://stats.nba.com/teams/traditional/?sort=PLUS_MINUS&dir=-1&Season=2018-19&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

trad_df_list19 = pd.read_html(table.prettify())

# %%
trad_19 = trad_df_list19[0]
trad_19["TEAM"] = trad_19["TEAM"].map(nba_2019)
trad_19.columns
# Out:
# Index(['Unnamed: 0', 'TEAM', 'GP', 'W', 'L', 'WIN%', 'MIN', 'PTS', 'FGM',
#        'FGA', 'FG%', '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB',
#        'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', '+/-',
#        'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
#        'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
#        'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
#        'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
#        'PF RANK', 'PFD RANK', '+/- RANK'],
#       dtype='object')

# %%
trad_19.drop(columns=['Unnamed: 0', 'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
       'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
       'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
       'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
       'PF RANK', 'PFD RANK', '+/- RANK'], inplace=True)
trad_19
# Out:
#                            TEAM  GP   W   L   WIN%   MIN    PTS   FGM   FGA  \
# 0          2019 Milwaukee Bucks  82  60  22  0.732  48.2  118.1  43.4  91.1
# 1    2019 Golden State Warriors  82  57  25  0.695  48.3  117.7  44.0  89.8
# 2          2019 Toronto Raptors  82  58  24  0.707  48.5  114.4  42.2  89.1
# 3                2019 Utah Jazz  82  50  32  0.610  48.2  111.7  40.4  86.4
# 4          2019 Houston Rockets  82  53  29  0.646  48.4  113.9  39.2  87.4
# 5           2019 Boston Celtics  82  49  33  0.598  48.2  112.4  42.1  90.5
# 6   2019 Portland Trail Blazers  82  53  29  0.646  48.4  114.7  42.3  90.6
# 7           2019 Denver Nuggets  82  54  28  0.659  48.1  110.7  41.9  90.0
# 8    2019 Oklahoma City Thunder  82  49  33  0.598  48.4  114.5  42.6  94.0
# 9           2019 Indiana Pacers  82  48  34  0.585  48.1  108.0  41.3  87.0
# 10      2019 Philadelphia 76ers  82  51  31  0.622  48.3  115.2  41.5  88.2
# ...

# %%
url = "https://stats.nba.com/teams/traditional/?sort=PLUS_MINUS&dir=-1&Season=2017-18&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

trad_df_list18 = pd.read_html(table.prettify())

# %%
trad_18 = trad_df_list18[0]
trad_18["TEAM"] = trad_18["TEAM"].map(nba_2018)

trad_18.drop(columns=['Unnamed: 0', 'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
       'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
       'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
       'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
       'PF RANK', 'PFD RANK', '+/- RANK'], inplace=True)
trad_18
# Out:
#                            TEAM  GP   W   L   WIN%   MIN    PTS   FGM   FGA  \
# 0          2018 Houston Rockets  82  65  17  0.793  48.2  112.4  38.7  84.2
# 1          2018 Toronto Raptors  82  59  23  0.720  48.4  111.7  41.3  87.4
# 2    2018 Golden State Warriors  82  58  24  0.707  48.1  113.5  42.8  85.1
# 3       2018 Philadelphia 76ers  82  52  30  0.634  48.2  109.8  40.8  86.6
# 4                2018 Utah Jazz  82  48  34  0.585  48.2  104.1  38.3  82.9
# 5           2018 Boston Celtics  82  55  27  0.671  48.3  104.0  38.3  85.1
# 6    2018 Oklahoma City Thunder  82  48  34  0.585  48.4  107.9  39.9  88.1
# 7        2018 San Antonio Spurs  82  47  35  0.573  48.1  102.7  39.0  85.4
# 8   2018 Portland Trail Blazers  82  49  33  0.598  48.2  105.6  39.3  87.0
# 9   2018 Minnesota Timberwolves  82  47  35  0.573  48.3  109.5  41.0  86.1
# 10          2018 Denver Nuggets  82  46  36  0.561  48.5  110.0  40.7  86.6
# ...

# %%
url = "https://stats.nba.com/teams/traditional/?sort=PLUS_MINUS&dir=-1&Season=2016-17&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

trad_df_list17 = pd.read_html(table.prettify())

# %%
trad_17 = trad_df_list17[0]
trad_17["TEAM"] = trad_17["TEAM"].map(nba_2017)

trad_17.drop(columns=['Unnamed: 0', 'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
       'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
       'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
       'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
       'PF RANK', 'PFD RANK', '+/- RANK'], inplace=True)
trad_17
# Out:
#                            TEAM  GP   W   L   WIN%   MIN    PTS   FGM   FGA  \
# 0    2017 Golden State Warriors  82  67  15  0.817  48.2  115.9  43.1  87.1
# 1        2017 San Antonio Spurs  82  61  21  0.744  48.3  105.3  39.3  83.7
# 2          2017 Houston Rockets  82  55  27  0.671  48.2  115.3  40.3  87.2
# 3              2017 LA Clippers  82  51  31  0.622  48.2  108.7  39.5  83.2
# 4          2017 Toronto Raptors  82  51  31  0.622  48.2  106.9  39.2  84.4
# 5                2017 Utah Jazz  82  51  31  0.622  48.2  100.7  37.0  79.5
# 6      2017 Cleveland Cavaliers  82  51  31  0.622  48.5  110.3  39.9  84.9
# 7           2017 Boston Celtics  82  53  29  0.646  48.2  108.0  38.6  85.1
# 8       2017 Washington Wizards  82  49  33  0.598  48.4  109.2  41.3  87.0
# 9               2017 Miami Heat  82  41  41  0.500  48.2  103.2  39.0  85.8
# 10   2017 Oklahoma City Thunder  82  47  35  0.573  48.3  106.6  39.5  87.4
# ...

# %%
reg_season_trad = pd.concat([trad_19, trad_18, trad_17])
reg_season_trad
# Out:
#                            TEAM  GP   W   L   WIN%   MIN    PTS   FGM   FGA  \
# 0          2019 Milwaukee Bucks  82  60  22  0.732  48.2  118.1  43.4  91.1
# 1    2019 Golden State Warriors  82  57  25  0.695  48.3  117.7  44.0  89.8
# 2          2019 Toronto Raptors  82  58  24  0.707  48.5  114.4  42.2  89.1
# 3                2019 Utah Jazz  82  50  32  0.610  48.2  111.7  40.4  86.4
# 4          2019 Houston Rockets  82  53  29  0.646  48.4  113.9  39.2  87.4
# 5           2019 Boston Celtics  82  49  33  0.598  48.2  112.4  42.1  90.5
# 6   2019 Portland Trail Blazers  82  53  29  0.646  48.4  114.7  42.3  90.6
# 7           2019 Denver Nuggets  82  54  28  0.659  48.1  110.7  41.9  90.0
# 8    2019 Oklahoma City Thunder  82  49  33  0.598  48.4  114.5  42.6  94.0
# 9           2019 Indiana Pacers  82  48  34  0.585  48.1  108.0  41.3  87.0
# 10      2019 Philadelphia 76ers  82  51  31  0.622  48.3  115.2  41.5  88.2
# ...

# %%
hustle_adv = pd.merge(reg_hustle_sorted, reg_adv_sorted, on='TEAM')
hustle_adv
# Out:
#                            TEAM  MIN_x  Screen  Assists  Screen  Assists PTS  \
# 0    2017 Golden State Warriors   96.5             12.8                 29.9
# 1       2017 Washington Wizards   96.9             11.7                 25.7
# 2       2017 Philadelphia 76ers   96.7              7.4                 16.9
# 3          2017 Toronto Raptors   96.5             12.1                 26.2
# 4    2018 Oklahoma City Thunder   96.7              9.6                 22.1
# 5            2017 Atlanta Hawks   97.0             10.8                 23.8
# 6           2017 Indiana Pacers   96.9             10.1                 23.0
# 7     2017 New Orleans Pelicans   97.1              8.5                 19.3
# 8           2018 Indiana Pacers   96.4              9.9                 21.9
# 9        2017 Memphis Grizzlies   97.1              8.2                 19.5
# 10  2017 Minnesota Timberwolves   96.6              8.9                 19.8
# ...

# %%
hustle_adv.columns
# Out:
# Index(['TEAM', 'MIN_x', 'Screen  Assists', 'Screen  Assists PTS',
#        'Deflections', 'OFF Loose Balls  Recovered',
#        'DEF Loose Balls  Recovered', 'Loose Balls  Recovered',
#        '% Loose Balls  Recovered OFF', '% Loose Balls  Recovered DEF',
#        'Charges  Drawn', 'Contested  2PT Shots', 'Contested  3PT Shots',
#        'Contested  Shots', 'GP', 'W', 'L', 'MIN_y', 'OffRtg', 'DefRtg',
#        'NetRtg', 'AST%', 'AST/TO', 'AST  Ratio', 'OREB%', 'DREB%', 'REB%',
#        'TOV%', 'eFG%', 'TS%', 'PACE', 'PIE', 'net_rtg_rank'],
#       dtype='object')

# %%
hustle_adv.rename(columns={'MIN_y': 'MIN'}, inplace=True)
hustle_adv.drop(columns=["MIN_x"], inplace=True)

hustle_adv.columns
# Out:
# Index(['TEAM', 'Screen  Assists', 'Screen  Assists PTS', 'Deflections',
#        'OFF Loose Balls  Recovered', 'DEF Loose Balls  Recovered',
#        'Loose Balls  Recovered', '% Loose Balls  Recovered OFF',
#        '% Loose Balls  Recovered DEF', 'Charges  Drawn',
#        'Contested  2PT Shots', 'Contested  3PT Shots', 'Contested  Shots',
#        'GP', 'W', 'L', 'MIN', 'OffRtg', 'DefRtg', 'NetRtg', 'AST%', 'AST/TO',
#        'AST  Ratio', 'OREB%', 'DREB%', 'REB%', 'TOV%', 'eFG%', 'TS%', 'PACE',
#        'PIE', 'net_rtg_rank'],
#       dtype='object')

# %%
hustle_adv_trad = pd.merge(hustle_adv, reg_season_trad, on='TEAM')
hustle_adv_trad
# Out:
#                            TEAM  Screen  Assists  Screen  Assists PTS  \
# 0    2017 Golden State Warriors             12.8                 29.9
# 1       2017 Washington Wizards             11.7                 25.7
# 2       2017 Philadelphia 76ers              7.4                 16.9
# 3          2017 Toronto Raptors             12.1                 26.2
# 4    2018 Oklahoma City Thunder              9.6                 22.1
# 5            2017 Atlanta Hawks             10.8                 23.8
# 6           2017 Indiana Pacers             10.1                 23.0
# 7     2017 New Orleans Pelicans              8.5                 19.3
# 8           2018 Indiana Pacers              9.9                 21.9
# 9        2017 Memphis Grizzlies              8.2                 19.5
# 10  2017 Minnesota Timberwolves              8.9                 19.8
# 11        2017 Sacramento Kings              7.8                 17.3
# ...

# %%
hustle_adv_trad.columns.to_list()
# Out:
# ['TEAM',
#  'Screen  Assists',
#  'Screen  Assists PTS',
#  'Deflections',
#  'OFF Loose Balls  Recovered',
#  'DEF Loose Balls  Recovered',
#  'Loose Balls  Recovered',
#  '% Loose Balls  Recovered OFF',
#  '% Loose Balls  Recovered DEF',
#  'Charges  Drawn',
#  'Contested 2PT Shots',
#  'Contested 3PT Shots',
#  'Contested  Shots',
#  'GP_x',
#  'W_x',
#  'L_x',
#  'MIN_x',
#  'OffRtg',
#  'DefRtg',
#  'NetRtg',
#  'AST%',
#  'AST/TO',
#  'AST  Ratio',
#  'OREB%',
#  'DREB%',
#  'REB%',
#  'TOV%',
#  'eFG%',
#  'TS%',
#  'PACE',
#  'PIE',
#  'net_rtg_rank',
#  'GP_y',
#  'W_y',
#  'L_y',
#  'WIN%',
#  'MIN_y',
#  'PTS',
#  'FGM',
#  'FGA',
#  'FG%',
#  '3PM',
#  '3PA',
#  '3P%',
#  'FTM',
#  'FTA',
#  'FT%',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'TOV',
#  'STL',
#  'BLK',
#  'BLKA',
#  'PF',
#  'PFD',
#  '+/-',
#  'deflection_rate',
#  'loose_ball_recover_rate',
#  'charges_drawn_rate',
#  'contest_rate']

# %%
hustle_adv_trad.rename(columns={'Contested  2PT\xa0Shots': 'Contested 2PT Shots', 
                       'Contested  3PT\xa0Shots': 'Contested 3PT Shots'}, inplace=True)

# %%
hustle_adv_trad['deflection_rate'] = hustle_adv_trad['Deflections']/hustle_adv_trad['PACE']
hustle_adv_trad['loose_ball_recover_rate'] = hustle_adv_trad['Loose Balls  Recovered']/hustle_adv_trad['PACE']
hustle_adv_trad['charges_drawn_rate'] = hustle_adv_trad['Charges  Drawn']/hustle_adv_trad['PACE']
hustle_adv_trad['contest_rate'] = hustle_adv_trad['Contested  Shots']/hustle_adv_trad['PACE']

# %%
hustle_adv_trad['contested_2pt_rate'] = hustle_adv_trad['Contested 2PT Shots']/hustle_adv_trad['PACE']
hustle_adv_trad['contested_3pt_rate'] = hustle_adv_trad['Contested 3PT Shots']/hustle_adv_trad['PACE']

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

hustle_adv_trad.corr()
# Out:
#                               Screen  Assists  Screen  Assists PTS  Deflections  OFF Loose Balls  Recovered  DEF Loose Balls  Recovered  Loose Balls  Recovered  % Loose Balls  Recovered OFF  % Loose Balls  Recovered DEF  Charges  Drawn  Contested 2PT Shots  Contested 3PT Shots  Contested  Shots  GP_x       W_x       L_x     MIN_x    OffRtg    DefRtg    NetRtg      AST%    AST/TO  AST  Ratio     OREB%     DREB%      REB%      TOV%      eFG%       TS%      PACE       PIE  net_rtg_rank  GP_y       W_y       L_y      WIN%     MIN_y       PTS       FGM       FGA       FG%       3PM       3PA       3P%       FTM       FTA       FT%      OREB      DREB       REB       AST       TOV       STL       BLK      BLKA        PF       PFD       +/-  deflection_rate  loose_ball_recover_rate  charges_drawn_rate  contest_rate  contested_2pt_rate  contested_3pt_rate
# ...

# %%
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
hustle_corr = hustle_adv_trad.corr()

hustle_writer = pd.ExcelWriter("nba_hustle_correlations_v2.xlsx", engine="xlsxwriter")

hustle_corr.to_excel(hustle_writer, sheet_name="correlations")

hustle_writer.save()

# %%
import seaborn as sn
from scipy                 import stats
from scipy.stats           import linregress
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
defense_only = hustle_adv_trad[['contested_2pt_rate', 'contested_3pt_rate', 'contest_rate', 'charges_drawn_rate',
                              'deflection_rate', 'loose_ball_recover_rate', 'STL', 'BLK', 'DREB%','DefRtg','NetRtg']]
defense_only.head()
# Out:
#    contested_2pt_rate  contested_3pt_rate  contest_rate  charges_drawn_rate  deflection_rate  loose_ball_recover_rate  STL  BLK  DREB%  DefRtg  NetRtg
# 0            0.458304            0.223174      0.681479            0.003886         0.186311                 0.076716  9.6  6.8   70.9   103.4    11.4
# 1            0.415561            0.217480      0.633041            0.006024         0.188891                 0.080662  8.5  4.1   71.6   108.8     1.7
# 2            0.432018            0.196831      0.628848            0.005653         0.179671                 0.076713  8.4  5.1   70.9   108.2    -5.5
# 3            0.437061            0.232680      0.668693            0.005136         0.178178                 0.074416  8.3  4.9   71.7   107.1     4.3
# 4            0.388330            0.247586      0.636943            0.004726         0.172591                 0.098623  9.1  5.0   72.5   106.4     3.7

# %%
fig, ax = plt.subplots(figsize=(9,7))

sn.heatmap(defense_only.corr(), annot=True, linewidths=0.5, ax=ax)

# %%
seasons = ["2016-17", "2017-18", "2018-19"]
last3_nba_seasons = [hustle_nba_2017["Deflections"].mean(), hustle_nba_2018["Deflections"].mean(), 
                  hustle_nba_19["Deflections"].mean()]

plt.bar(seasons, last3_nba_seasons, color="orange", align="center")
plt.title("NBA Regular Season Deflections Per Game 2016-2019")
plt.xlabel("NBA Seasons")
plt.ylabel("Deflections")
plt.ylim(10, max(last3_nba_seasons)+0.5)

plt.savefig("deflections_per_game.png")

# %%
three_seasons_adv = [advanced_17['DefRtg'].mean(), advanced_18['DefRtg'].mean(), advanced_19['DefRtg'].mean()]

plt.bar(seasons, three_seasons_adv, color="red", align="center")
plt.title("NBA Defensive Ratings 2016-2019")
plt.xlabel("NBA Seasons")
plt.ylabel("DefRtg")
plt.ylim(105, max(three_seasons_adv)+0.5)

plt.savefig("drtg.png")

# %%
three_seasons_pace = [advanced_17['PACE'].mean(), advanced_18['PACE'].mean(), advanced_19['PACE'].mean()]

plt.bar(seasons, three_seasons_pace, color="silver", align="center")
plt.title("NBA Pace 2016-2019")
plt.xlabel("NBA Seasons")
plt.ylabel("Pace")
plt.ylim(90, max(three_seasons_pace)+0.5)

plt.savefig("pace.png")

# %%
# %matplotlib notebook

x_axis = hustle_adv_trad["deflection_rate"]
y_axis = hustle_adv_trad["DefRtg"]

#Fit regression lines
slope, intercept, r_value, p_value, std_err = stats.linregress(x_axis, y_axis)
r   = "{:.3f}".format(r_value**2)
slp = "{:.3f}".format(slope)
pv  = "{:.2E}".format(p_value)
textbox1 = f"R-squared= {r}"
textbox2 = f"slope={slp}, p-value= {pv}"

#Plot scatterplot and regression line
sn.regplot(x=x_axis, y=y_axis, data=hustle_adv_trad, color="black")
x_axis = hustle_adv_trad["deflection_rate"]
y_axis = hustle_adv_trad["DefRtg"]


plt.scatter(x_axis, y_axis, marker="o", facecolors="gold", edgecolors="grey", alpha=1)
plt.text(0.15,116,textbox1, size='medium', weight='light', fontsize=10)
plt.text(0.15,115,textbox2, size='medium', weight='light', fontsize=10)

#Edit
plt.title("NBA 2016-2019: Deflection Rate vs. Defensive Rating")

#Show ad save figure
plt.savefig("deflection_rate_vs_drtg.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib notebook

#Fit regression lines
slope, intercept, r_value, p_value, std_err = stats.linregress(x_axis, y_axis)
r   = "{:.3f}".format(r_value**2)
slp = "{:.3f}".format(slope)
pv  = "{:.2E}".format(p_value)
textbox1 = f"R-squared= {r}"
textbox2 = f"slope={slp}, p-value= {pv}"

#Plot scatterplot and regression line
sn.regplot(x=x_axis, y=y_axis, data=hustle_adv_trad, color="black")
x_axis = hustle_adv_trad["contested_2pt_rate"]
y_axis = hustle_adv_trad["DefRtg"]


plt.scatter(x_axis, y_axis, marker="o", facecolors="royalblue", edgecolors="black", alpha=1)
plt.text(0.405,116,textbox1, size='medium', weight='light', fontsize=10)
plt.text(0.405,115,textbox2, size='medium', weight='light', fontsize=10)

#Edit
plt.title("NBA 2016-2019: 2-pt Contest Rate vs. Defensive Rating")

#Show ad save figure
plt.savefig("2pt_contest_rate_drtg.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib notebook

x_axis = hustle_adv_trad["contested_3pt_rate"]
y_axis = hustle_adv_trad["DefRtg"]

#Fit regression lines
slope, intercept, r_value, p_value, std_err = stats.linregress(x_axis, y_axis)
r   = "{:.3f}".format(r_value**2)
slp = "{:.3f}".format(slope)
pv  = "{:.2E}".format(p_value)
textbox1 = f"R-squared= {r}"
textbox2 = f"slope={slp}, p-value= {pv}"

#Plot scatterplot and regression line
sn.regplot(x=x_axis, y=y_axis, data=hustle_adv_trad, color="black")
x_axis = hustle_adv_trad["contested_3pt_rate"]
y_axis = hustle_adv_trad["DefRtg"]


plt.scatter(x_axis, y_axis, marker="o", facecolors="royalblue", edgecolors="black", alpha=1)
plt.text(0.18,116,textbox1, size='medium', weight='light', fontsize=10)
plt.text(0.18,115,textbox2, size='medium', weight='light', fontsize=10)

#Edit
plt.title("NBA 2016-2019: 3-pt Contest Rate vs. Defensive Rating")

#Show ad save figure
plt.savefig("3pt_contest_rate_drtg.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
seasons = ["2016-17", "2017-18", "2018-19"]
two_pt_contests = [hustle_nba_2017["Contested  2PT\xa0Shots"].mean(), hustle_nba_2018["Contested  2PT\xa0Shots"].mean(), 
                  hustle_nba_19["Contested  2PT\xa0Shots"].mean()]

plt.bar(seasons, two_pt_contests, color="green", align="center")
plt.title("NBA Team 2PT Contests Per Game 2016-2019")
plt.xlabel("NBA Seasons")
plt.ylabel("2PT Contests")
plt.ylim(30, max(two_pt_contests)+0.75)

plt.savefig("2pt_contests_per_game.png")
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
hustle_adv_19 = pd.merge(hustle_nba_19, advanced_19, on='TEAM')
hustle_adv_trad19 = pd.merge(hustle_adv_19, trad_19, on='TEAM')
hustle_adv_trad19
# Out:
#                            TEAM  MIN_x  Screen  Assists  Screen  Assists PTS  Deflections  OFF Loose Balls  Recovered  DEF Loose Balls  Recovered  Loose Balls  Recovered  % Loose Balls  Recovered OFF  % Loose Balls  Recovered DEF  Charges  Drawn  Contested  2PT Shots  Contested  3PT Shots  Contested  Shots  GP_x  W_x  L_x   MIN_y  OffRtg  DefRtg  NetRtg  AST%  AST/TO  AST  Ratio  OREB%  DREB%  REB%  TOV%  eFG%   TS%    PACE   PIE  GP_y  W_y  L_y   WIN%   MIN    PTS   FGM   FGA   FG%   3PM   3PA   3P%   FTM   FTA   FT%  OREB  DREB   REB   AST   TOV  STL  BLK  BLKA    PF   PFD  +/-
# ...

# %%
hustle_adv_trad19.columns.to_list()
# Out:
# ['TEAM',
#  'MIN_x',
#  'Screen  Assists',
#  'Screen  Assists PTS',
#  'Deflections',
#  'OFF Loose Balls  Recovered',
#  'DEF Loose Balls  Recovered',
#  'Loose Balls  Recovered',
#  '% Loose Balls  Recovered OFF',
#  '% Loose Balls  Recovered DEF',
#  'Charges  Drawn',
#  'Contested  2PT\xa0Shots',
#  'Contested  3PT\xa0Shots',
#  'Contested  Shots',
#  'GP_x',
#  'W_x',
#  'L_x',
#  'MIN_y',
#  'OffRtg',
#  'DefRtg',
#  'NetRtg',
#  'AST%',
#  'AST/TO',
#  'AST  Ratio',
#  'OREB%',
#  'DREB%',
#  'REB%',
#  'TOV%',
#  'eFG%',
#  'TS%',
#  'PACE',
#  'PIE',
#  'GP_y',
#  'W_y',
#  'L_y',
#  'WIN%',
#  'MIN',
#  'PTS',
#  'FGM',
#  'FGA',
#  'FG%',
#  '3PM',
#  '3PA',
#  '3P%',
#  'FTM',
#  'FTA',
#  'FT%',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'TOV',
#  'STL',
#  'BLK',
#  'BLKA',
#  'PF',
#  'PFD',
#  '+/-']

# %%
hustle_adv_trad19.rename(columns={'Contested  2PT\xa0Shots': 'Contested 2PT Shots', 
                       'Contested  3PT\xa0Shots': 'Contested 3PT Shots'}, inplace=True)

# %%
hustle_adv_trad19['deflection_rate'] = hustle_adv_trad19['Deflections']/hustle_adv_trad19['PACE']
hustle_adv_trad19['loose_ball_recover_rate'] = hustle_adv_trad19['Loose Balls  Recovered']/hustle_adv_trad19['PACE']
hustle_adv_trad19['charges_drawn_rate'] = hustle_adv_trad19['Charges  Drawn']/hustle_adv_trad19['PACE']
hustle_adv_trad19['contest_rate'] = hustle_adv_trad19['Contested  Shots']/hustle_adv_trad19['PACE']
hustle_adv_trad19['contested_2pt_rate'] = hustle_adv_trad19['Contested 2PT Shots']/hustle_adv_trad19['PACE']
hustle_adv_trad19['contested_3pt_rate'] = hustle_adv_trad19['Contested 3PT Shots']/hustle_adv_trad19['PACE']

# %%
defense_only19 = hustle_adv_trad19[['contested_2pt_rate', 'contested_3pt_rate', 'contest_rate', 'charges_drawn_rate',
                              'deflection_rate', 'loose_ball_recover_rate', 'STL', 'BLK', 'DREB%','DefRtg','NetRtg']]
defense_only19.head()
# Out:
#    contested_2pt_rate  contested_3pt_rate  contest_rate  charges_drawn_rate  deflection_rate  loose_ball_recover_rate  STL  BLK  DREB%  DefRtg  NetRtg
# 0            0.363428            0.241010      0.604438            0.004878         0.138676                 0.090857  8.2  5.1   71.8   113.1    -5.5
# 1            0.357463            0.262870      0.620333            0.006671         0.140396                 0.082645  8.6  5.3   72.8   107.0     4.3
# 2            0.438380            0.218698      0.657078            0.003152         0.119200                 0.078810  6.6  4.1   72.0   109.0    -0.1
# 3            0.395241            0.255092      0.650333            0.006050         0.127042                 0.081670  7.2  4.9   73.1   112.0    -1.3
# 4            0.367573            0.250755      0.617321            0.004129         0.126888                 0.079557  7.4  4.3   72.7   112.8    -8.3

# %%
fig, ax = plt.subplots(figsize=(14,14))

sn.heatmap(defense_only19.corr(), annot=True, linewidths=0.5, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
hustle_adv18 = pd.merge(hustle_nba_2018, advanced_18, on='TEAM')
hustle_adv_trad18 = pd.merge(hustle_adv18, trad_18, on='TEAM')
hustle_adv_trad18
# Out:
#                            TEAM  MIN_x  Screen  Assists  Screen  Assists PTS  Deflections  OFF Loose Balls  Recovered  DEF Loose Balls  Recovered  Loose Balls  Recovered  % Loose Balls  Recovered OFF  % Loose Balls  Recovered DEF  Charges  Drawn  Contested  2PT Shots  Contested  3PT Shots  Contested  Shots  GP_x  W_x  L_x   MIN_y  OffRtg  DefRtg  NetRtg  AST%  AST/TO  AST  Ratio  OREB%  DREB%  REB%  TOV%  eFG%   TS%    PACE   PIE  GP_y  W_y  L_y   WIN%   MIN    PTS   FGM   FGA   FG%   3PM   3PA   3P%   FTM   FTA   FT%  OREB  DREB   REB   AST   TOV  STL  BLK  BLKA    PF   PFD  +/-
# ...

# %%
hustle_adv_trad18.rename(columns={'Contested  2PT\xa0Shots': 'Contested 2PT Shots', 
                       'Contested  3PT\xa0Shots': 'Contested 3PT Shots'}, inplace=True)

# %%
hustle_adv_trad18['deflection_rate'] = hustle_adv_trad18['Deflections']/hustle_adv_trad18['PACE']
hustle_adv_trad18['loose_ball_recover_rate'] = hustle_adv_trad18['Loose Balls  Recovered']/hustle_adv_trad18['PACE']
hustle_adv_trad18['charges_drawn_rate'] = hustle_adv_trad18['Charges  Drawn']/hustle_adv_trad18['PACE']
hustle_adv_trad18['contest_rate'] = hustle_adv_trad18['Contested  Shots']/hustle_adv_trad18['PACE']
hustle_adv_trad18['contested_2pt_rate'] = hustle_adv_trad18['Contested 2PT Shots']/hustle_adv_trad18['PACE']
hustle_adv_trad18['contested_3pt_rate'] = hustle_adv_trad18['Contested 3PT Shots']/hustle_adv_trad18['PACE']

# %%
defense_only18 = hustle_adv_trad18[['contested_2pt_rate', 'contested_3pt_rate', 'contest_rate', 'charges_drawn_rate',
                              'deflection_rate', 'loose_ball_recover_rate', 'STL', 'BLK', 'DREB%','DefRtg','NetRtg']]
defense_only18.head()
# Out:
#    contested_2pt_rate  contested_3pt_rate  contest_rate  charges_drawn_rate  deflection_rate  loose_ball_recover_rate  STL  BLK  DREB%  DefRtg  NetRtg
# 0            0.378827            0.220129      0.599980            0.008191         0.152555                 0.081908  7.9  4.3   73.2   107.7     0.4
# 1            0.426589            0.221578      0.648167            0.002796         0.156347                 0.082833  8.6  5.1   75.6   103.0     4.4
# 2            0.458070            0.197919      0.655989            0.008570         0.150990                 0.085697  7.6  6.1   72.5   105.3     7.7
# 3            0.460815            0.211076      0.672936            0.005434         0.150470                 0.084639  7.7  5.6   74.1   104.1     3.0
# 4            0.379058            0.269110      0.648168            0.002513         0.146597                 0.086911  7.8  4.1   73.1   110.4    -7.3

# %%
fig, ax = plt.subplots(figsize=(14,14))

sn.heatmap(defense_only18.corr(), annot=True, linewidths=0.5, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
hustle_adv17 = pd.merge(hustle_nba_2017, advanced_17, on='TEAM')
hustle_adv_trad17 = pd.merge(hustle_adv17, trad_17, on='TEAM')
hustle_adv_trad17
# Out:
#                            TEAM  MIN_x  Screen  Assists  Screen  Assists PTS  Deflections  OFF Loose Balls  Recovered  DEF Loose Balls  Recovered  Loose Balls  Recovered  % Loose Balls  Recovered OFF  % Loose Balls  Recovered DEF  Charges  Drawn  Contested  2PT Shots  Contested  3PT Shots  Contested  Shots  GP_x  W_x  L_x   MIN_y  OffRtg  DefRtg  NetRtg  AST%  AST/TO  AST  Ratio  OREB%  DREB%  REB%  TOV%  eFG%   TS%    PACE   PIE  GP_y  W_y  L_y   WIN%   MIN    PTS   FGM   FGA   FG%   3PM   3PA   3P%   FTM   FTA   FT%  OREB  DREB   REB   AST   TOV  STL  BLK  BLKA    PF   PFD   +/-
# ...

# %%
hustle_adv_trad17.rename(columns={'Contested  2PT\xa0Shots': 'Contested 2PT Shots', 
                       'Contested  3PT\xa0Shots': 'Contested 3PT Shots'}, inplace=True)

# %%
hustle_adv_trad17['deflection_rate'] = hustle_adv_trad17['Deflections']/hustle_adv_trad17['PACE']
hustle_adv_trad17['loose_ball_recover_rate'] = hustle_adv_trad17['Loose Balls  Recovered']/hustle_adv_trad17['PACE']
hustle_adv_trad17['charges_drawn_rate'] = hustle_adv_trad17['Charges  Drawn']/hustle_adv_trad17['PACE']
hustle_adv_trad17['contest_rate'] = hustle_adv_trad17['Contested  Shots']/hustle_adv_trad17['PACE']
hustle_adv_trad17['contested_2pt_rate'] = hustle_adv_trad17['Contested 2PT Shots']/hustle_adv_trad17['PACE']
hustle_adv_trad17['contested_3pt_rate'] = hustle_adv_trad17['Contested 3PT Shots']/hustle_adv_trad17['PACE']

# %%
defense_only17 = hustle_adv_trad17[['contested_2pt_rate', 'contested_3pt_rate', 'contest_rate', 'charges_drawn_rate',
                              'deflection_rate', 'loose_ball_recover_rate', 'STL', 'BLK', 'DREB%','DefRtg','NetRtg']]
defense_only17.head()
# Out:
#    contested_2pt_rate  contested_3pt_rate  contest_rate  charges_drawn_rate  deflection_rate  loose_ball_recover_rate  STL  BLK  DREB%  DefRtg  NetRtg
# 0            0.414280            0.244476      0.657733            0.009718         0.171849                 0.068535  8.2  4.8   71.7   105.2    -0.7
# 1            0.416624            0.234544      0.650139            0.007818         0.158420                 0.077153  7.5  4.1   70.5   108.0     2.6
# 2            0.482555            0.220147      0.702703            0.005504         0.141523                 0.069779  7.2  4.7   71.6   110.1    -6.5
# 3            0.443078            0.265847      0.708924            0.006776         0.143870                 0.067765  7.0  4.8   74.9   108.4     0.0
# 4            0.465528            0.214539      0.680067            0.003645         0.155176                 0.074984  7.8  4.8   73.3   106.2     0.3

# %%
fig, ax = plt.subplots(figsize=(14,14))

sn.heatmap(defense_only18.corr(), annot=True, linewidths=0.5, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
# 2019-20 NBA regular season through 1/5/2020

url = "https://stats.nba.com/teams/advanced/?sort=W&dir=-1"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

adv_df_list20 = pd.read_html(table.prettify())

# %%
def nba_2020(team):
    return "2020 {:}".format(team)

# %%
advanced_20 = adv_df_list20[0]
advanced_20["TEAM"] = advanced_20["TEAM"].map(nba_2020)
advanced_20.head()

# %%
advanced_20.drop(columns=['GP RANK', 'W RANK', 'L RANK',
       'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
       'AST/TO RANK', 'AST  Ratio RANK', 'OREB% RANK', 'DREB% RANK',
       'REB% RANK', 'TO  Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
       'PIE RANK'], inplace=True)

advanced_20.drop(columns=["Unnamed: 0"], inplace=True)
advanced_20.head()

# %%
url = "https://stats.nba.com/teams/hustle/?Season=2019-20&SeasonType=Regular%20Season"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

hustle_df_list20 = pd.read_html(table.prettify())

# %%
hustle_20 = hustle_df_list20[0]
hustle_20["TEAM"] = hustle_20["TEAM"].map(nba_2020)

hustle_20.rename(columns={'Contested  2PT\xa0Shots': 'Contested 2PT Shots',
                                   'Contested  3PT\xa0Shots': 'Contested 3PT Shots'},
                         inplace=True)
hustle_20.head()

# %%
url = "https://stats.nba.com/teams/traditional/?sort=W_PCT&dir=-1"
driver = webdriver.Chrome(executable_path=r"C:\Users\chris\OneDrive\nba_hustle_stats\chromedriver.exe")
driver.get(url)
htmlSource = driver.page_source

soup = BeautifulSoup(htmlSource, 'html.parser')
table = soup.find('div', class_='nba-stat-table__overflow')

trad_df_list20 = pd.read_html(table.prettify())

# %%
trad_20 = trad_df_list20[0]
trad_20["TEAM"] = trad_20["TEAM"].map(nba_2020)

trad_20.drop(columns=['Unnamed: 0', 'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
       'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
       'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
       'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
       'PF RANK', 'PFD RANK', '+/- RANK'], inplace=True)
trad_20

# %%
advanced_20.head()

# %%
reg_20 = pd.merge(hustle_20, advanced_20, on='TEAM')
reg_20

# %%
seasons20 = ["2016-17", "2017-18", "2018-19", "2019-20"]
deflection_rates = [hustle_adv_trad17['deflection_rate'].mean(), hustle_adv_trad18['deflection_rate'].mean(), 
                  hustle_adv_trad19['deflection_rate'].mean(), 0.149]

plt.bar(seasons20, deflection_rates, color="green", align="center")
plt.title("NBA Team Deflection Rates 2016-2020")
plt.xlabel("NBA Seasons")
plt.ylabel("Deflection Rates")
plt.ylim(0.115, max(deflection_rates)+0.005)

plt.savefig("deflection_rates20.png")

# %%
seasons20 = ["2016-17", "2017-18", "2018-19", "2019-20"]
defensive_ratings = [hustle_adv_trad17['DefRtg'].mean(), hustle_adv_trad18['DefRtg'].mean(), 
                  hustle_adv_trad19['DefRtg'].mean(), 108.37]

plt.bar(seasons20, defensive_ratings, color="red", align="center")
plt.title("NBA Defensive Rating 2016-2020")
plt.xlabel("NBA Seasons")
plt.ylabel("Defensive Rating")
plt.ylim(106.75, max(defensive_ratings)+0.5)

plt.savefig("d_ratings_20.png")
